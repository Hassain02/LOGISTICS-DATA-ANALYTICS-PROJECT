# %%
import pandas as pd

# %%
df= pd.read_excel(r"C:\Users\LENOVO\Downloads\Unclean_Logistics_Dataset_12000plus_Rows.xlsx")

# %%
df.dtypes
# Out:
# Shipment_ID                    object
# Order_Date                     object
# Ship_Date                      object
# Delivery_Date                  object
# Origin                         object
# Destination                    object
# Transport_Mode                 object
# Carrier                        object
# Shipment_Status                object
# Warehouse_ID                   object
# Product_Category               object
# Distance_km                   float64
# Shipment_Weight_kg            float64
# Quantity                        int64
# Shipping_Cost_INR             float64
# Promised_Delivery_Days          int64
# Actual_Delivery_Days            int64
# Customer_Rating               float64
# Fuel_Surcharge_INR            float64
# Warehouse_Processing_Hours    float64
# Temperature_C                 float64
# dtype: object

# %%
df.shape
# Out:
# (12150, 21)

# %%
df.describe(include="all")
# Out:
#        Shipment_ID  Order_Date   Ship_Date Delivery_Date Origin Destination  \
# count        12150       12150       12150         12150  12129       12150
# unique       12000         551         367           375     24          24
# top      SHP105637  2025-04-28  2025-08-05    2025-04-18   Pune   Ahmedabad
# freq             2          50          51            51   1060        1051
# mean           NaN         NaN         NaN           NaN    NaN         NaN
# std            NaN         NaN         NaN           NaN    NaN         NaN
# min            NaN         NaN         NaN           NaN    NaN         NaN
# 25%            NaN         NaN         NaN           NaN    NaN         NaN
# 50%            NaN         NaN         NaN           NaN    NaN         NaN
# 75%            NaN         NaN         NaN           NaN    NaN         NaN
# max            NaN         NaN         NaN           NaN    NaN         NaN
#
#        Transport_Mode   Carrier Shipment_Status Warehouse_ID  ...  \
# count           12150     11830           12150        12150  ...
# unique             11         7               9            6  ...
# top             rail   BlueDart       delivered    WH-BLR-01  ...
# freq             1989      1762            2052         2053  ...
# mean              NaN       NaN             NaN          NaN  ...
# std               NaN       NaN             NaN          NaN  ...
# min               NaN       NaN             NaN          NaN  ...
# 25%               NaN       NaN             NaN          NaN  ...
# 50%               NaN       NaN             NaN          NaN  ...
# 75%               NaN       NaN             NaN          NaN  ...
# max               NaN       NaN             NaN          NaN  ...
#
#          Distance_km  Shipment_Weight_kg      Quantity  Shipping_Cost_INR  \
# count   11972.000000        12150.000000  12150.000000       12150.000000
# unique           NaN                 NaN           NaN                NaN
# top              NaN                 NaN           NaN                NaN
# freq             NaN                 NaN           NaN                NaN
# mean     1257.983628           18.147844     15.556955       12541.200593
# std       717.800527            8.894087      8.586236       24562.632342
# min      -100.000000           -5.000000      1.000000       -5000.000000
# 25%       636.000000           12.000000      8.000000        5731.725000
# 50%      1262.000000           18.000000     16.000000       10493.730000
# 75%      1886.000000           24.200000     23.000000       16375.100000
# max      2500.000000           57.400000     30.000000      872774.000000
#
#         Promised_Delivery_Days  Actual_Delivery_Days  Customer_Rating  \
# count             12150.000000          12150.000000      8011.000000
# unique                     NaN                   NaN              NaN
# top                        NaN                   NaN              NaN
# freq                       NaN                   NaN              NaN
# mean                  3.692510              3.895473         2.996754
# std                   1.968875              3.912590         1.416944
# min                   1.000000              0.000000         1.000000
# 25%                   2.000000              2.000000         2.000000
# 50%                   4.000000              4.000000         3.000000
# 75%                   5.000000              6.000000         4.000000
# max                   7.000000             89.000000         5.000000
#
#         Fuel_Surcharge_INR  Warehouse_Processing_Hours  Temperature_C
# count         12150.000000                11907.000000   11966.000000
# unique                 NaN                         NaN            NaN
# top                    NaN                         NaN            NaN
# freq                   NaN                         NaN            NaN
# mean           1872.108882                   12.002813      28.005173
# std            1344.362824                    5.019498       5.032268
# min              10.830000                    0.200000       9.100000
# 25%             789.572500                    8.600000      24.600000
# 50%            1578.180000                   12.000000      28.100000
# 75%            2724.295000                   15.400000      31.400000
# max            6160.930000                   31.100000      46.700000
#
# [11 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12150 entries, 0 to 12149
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Shipment_ID                 12150 non-null  object
#  1   Order_Date                  12150 non-null  object
#  2   Ship_Date                   12150 non-null  object
#  3   Delivery_Date               12150 non-null  object
#  4   Origin                      12129 non-null  object
#  5   Destination                 12150 non-null  object
#  6   Transport_Mode              12150 non-null  object
#  7   Carrier                     11830 non-null  object
#  8   Shipment_Status             12150 non-null  object
#  9   Warehouse_ID                12150 non-null  object
#  10  Product_Category            12009 non-null  object
#  11  Distance_km                 11972 non-null  float64
#  12  Shipment_Weight_kg          12150 non-null  float64
#  13  Quantity                    12150 non-null  int64
#  14  Shipping_Cost_INR           12150 non-null  float64
#  15  Promised_Delivery_Days      12150 non-null  int64
#  16  Actual_Delivery_Days        12150 non-null  int64
#  17  Customer_Rating             8011 non-null   float64
#  18  Fuel_Surcharge_INR          12150 non-null  float64
#  19  Warehouse_Processing_Hours  11907 non-null  float64
#  20  Temperature_C               11966 non-null  float64
# dtypes: float64(7), int64(3), object(11)
# memory usage: 1.9+ MB

# %%
df.isnull().sum()
# Out:
# Shipment_ID                      0
# Order_Date                       0
# Ship_Date                        0
# Delivery_Date                    0
# Origin                          21
# Destination                      0
# Transport_Mode                   0
# Carrier                        320
# Shipment_Status                  0
# Warehouse_ID                     0
# Product_Category               141
# Distance_km                    178
# Shipment_Weight_kg               0
# Quantity                         0
# Shipping_Cost_INR                0
# Promised_Delivery_Days           0
# Actual_Delivery_Days             0
# Customer_Rating               4139
# Fuel_Surcharge_INR               0
# Warehouse_Processing_Hours     243
# Temperature_C                  184
# dtype: int64
